# %% [markdown]
# <a href="https://colab.research.google.com/github/RatihParamita/dataMining/blob/main/Percobaan1Week16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Install library

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
# Libraries for Leaky ReLu, Parametric ReLu, ELU, Softmax, and Binary Step Activation
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LeakyReLU, PReLU, ELU, Softmax, Activation
# Library for Swish, GELU, and SELU Activation
from tensorflow.keras.activations import swish, gelu, selu
# Import necessary modules
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.metrics import r2_score

# %% [markdown]
# Fungsi kustom Binary Step Activation

# %%
# def binary_step(x):
    # return tf.where(x > 0, tf.ones_like(x), tf.zeros_like(x))

# %% [markdown]
# Membaca data

# %%
df = pd.read_csv('Dataset Diabetes.csv')
print(df.shape)
df.describe().transpose()
# Out:
# (768, 9)
#                           count        mean         std  ...       50%        75%     max
# Pregnancies               768.0    3.845052    3.369578  ...    3.0000    6.00000   17.00
# Glucose                   768.0  120.894531   31.972618  ...  117.0000  140.25000  199.00
# BloodPressure             768.0   69.105469   19.355807  ...   72.0000   80.00000  122.00
# SkinThickness             768.0   20.536458   15.952218  ...   23.0000   32.00000   99.00
# Insulin                   768.0   79.799479  115.244002  ...   30.5000  127.25000  846.00
# BMI                       768.0   31.992578    7.884160  ...   32.0000   36.60000   67.10
# DiabetesPedigreeFunction  768.0    0.471876    0.331329  ...    0.3725    0.62625    2.42
# Age                       768.0   33.240885   11.760232  ...   29.0000   41.00000   81.00
# Outcome                   768.0    0.348958    0.476951  ...    0.0000    1.00000    1.00
#
# [9 rows x 8 columns]

# %% [markdown]
# Membuat fitur dan target

# %%
target_column = ['Outcome']
predictors = list(set(list(df.columns))-set(target_column))
df[predictors] = df[predictors]/df[predictors].max()
df.describe().transpose()
# Out:
#                           count      mean       std       min       25%       50%       75%  max
# Pregnancies               768.0  0.226180  0.198210  0.000000  0.058824  0.176471  0.352941  1.0
# Glucose                   768.0  0.607510  0.160666  0.000000  0.497487  0.587940  0.704774  1.0
# BloodPressure             768.0  0.566438  0.158654  0.000000  0.508197  0.590164  0.655738  1.0
# SkinThickness             768.0  0.207439  0.161134  0.000000  0.000000  0.232323  0.323232  1.0
# Insulin                   768.0  0.094326  0.136222  0.000000  0.000000  0.036052  0.150414  1.0
# BMI                       768.0  0.476790  0.117499  0.000000  0.406855  0.476900  0.545455  1.0
# DiabetesPedigreeFunction  768.0  0.194990  0.136913  0.032231  0.100723  0.153926  0.258781  1.0
# Age                       768.0  0.410381  0.145188  0.259259  0.296296  0.358025  0.506173  1.0
# Outcome                   768.0  0.348958  0.476951  0.000000  0.000000  0.000000  1.000000  1.0

# %% [markdown]
# Membuat data training dan testing

# %%
X = df[predictors].values
y = df[target_column].values

# Konversi variabel target ke kategorikal (one-hot encoding) untuk Softmax, Swish, GELU, SELU, dan Binary Step Acivation
y = tf.keras.utils.to_categorical(y, num_classes=2)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=40)
print(X_train.shape); print(X_test.shape)
# Out:
# (537, 8)
# (231, 8)

# %% [markdown]
# Modelling Multilayer Perceptron

# %%
from sklearn.neural_network import MLPClassifier

# Menggunakan ReLu Activation
# mlp = MLPClassifier(hidden_layer_sizes=(7,10,8), activation='relu', solver='adam', max_iter=500)
# mlp.fit(X_train, y_train.)
# predict_train = mlp.predict(X_train)
# predict_test = mlp.predict(X_test)

# Menggunakan Sigmoid/Logistic Activation
# mlp = MLPClassifier(hidden_layer_sizes=(6,9,1), activation='logistic', solver='adam', max_iter=500)
# mlp.fit(X_train, y_train.ravel())
# predict_train = mlp.predict(X_train)
# predict_test = mlp.predict(X_test)

# Menggunakan Tanh Activation
# mlp = MLPClassifier(hidden_layer_sizes=(6,9,1), activation='tanh', solver='adam', max_iter=500)
# mlp.fit(X_train, y_train.ravel())
# predict_train = mlp.predict(X_train)
# predict_test = mlp.predict(X_test)

# Menggunakan Leaky ReLu Activation
# model = Sequential()
# model.add(Dense(6, input_dim=X_train.shape[1]))
# model.add(LeakyReLU(alpha=0.01))
# model.add(Dense(9))
# model.add(LeakyReLU(alpha=0.01))
# model.add(Dense(1))
# model.add(LeakyReLU(alpha=0.01))
# model.add(Dense(1, activation='sigmoid'))  # Layer output dengan Sigmoid Activation untuk klasifikasi binary
# model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# model.fit(X_train, y_train, epochs=100, batch_size=10, verbose=1)
# y_pred_train = model.predict(X_train)
# y_pred_train = (y_pred_train > 0.5).astype(int)
# y_pred_test = model.predict(X_test)
# y_pred_test = (y_pred_test > 0.5).astype(int)

# Menggunakan Parametric ReLu Activation
# model = Sequential()
# model.add(Dense(6, input_dim=X_train.shape[1]))
# model.add(PReLU())
# model.add(Dense(9))
# model.add(PReLU())
# model.add(Dense(1))
# model.add(PReLU())
# model.add(Dense(1, activation='sigmoid')) # Layer output dengan Sigmoid Activation untuk klasifikasi binary
# model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# model.fit(X_train, y_train, epochs=100, batch_size=10, verbose=1)
# y_pred_train = model.predict(X_train)
# y_pred_train = (y_pred_train > 0.5).astype(int)
# y_pred_test = model.predict(X_test)
# y_pred_test = (y_pred_test > 0.5).astype(int)

# Menggunakan ELU Activation
# model = Sequential()
# model.add(Dense(6, input_dim=X_train.shape[1]))
# model.add(ELU(alpha=1.0))
# model.add(Dense(9))
# model.add(ELU(alpha=1.0))
# model.add(Dense(1))
# model.add(ELU(alpha=1.0))
# model.add(Dense(1, activation='sigmoid')) # Layer output dengan Sigmoid Activation untuk klasifikasi binary
# model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# model.fit(X_train, y_train, epochs=100, batch_size=10, verbose=1)
# y_pred_train = model.predict(X_train)
# y_pred_train = (y_pred_train > 0.5).astype(int)
# y_pred_test = model.predict(X_test)
# y_pred_test = (y_pred_test > 0.5).astype(int)

# Menggunakan Softmax Activation
# model = Sequential()
# model.add(Dense(6, input_dim=X_train.shape[1], activation='relu'))
# model.add(Dense(9, activation='relu'))
# model.add(Dense(1, activation='relu'))
# model.add(Dense(2))  # Layer output untuk klasifikasi binary dengan 2 output
# model.add(Softmax())  # Softmax activation untuk layer output
# model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# model.fit(X_train, y_train, epochs=100, batch_size=10, verbose=1)
# y_pred_train = model.predict(X_train)
# y_pred_train = (y_pred_train.argmax(axis=1)).astype(int)
# y_pred_test = model.predict(X_test)
# y_pred_test = (y_pred_test.argmax(axis=1)).astype(int)
# y_train_single = y_train.argmax(axis=1)
# y_test_single = y_test.argmax(axis=1)

# Menggunakan Swish Activation
# model = Sequential()
# model.add(Dense(6, input_dim=X_train.shape[1], activation='swish'))
# model.add(Dense(9, activation='swish'))
# model.add(Dense(1, activation='swish'))
# model.add(Dense(2, activation='softmax'))  # Layer output layer dengan softmax activation untuk klasifikasi binary
# model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# model.fit(X_train, y_train, epochs=100, batch_size=10, verbose=1)
# y_pred_train = model.predict(X_train)
# y_pred_train = (y_pred_train.argmax(axis=1)).astype(int)
# y_pred_test = model.predict(X_test)
# y_pred_test = (y_pred_test.argmax(axis=1)).astype(int)
# y_train_single = y_train.argmax(axis=1)
# y_test_single = y_test.argmax(axis=1)

# Menggunakan GELU Activation
# model = Sequential()
# model.add(Dense(6, input_dim=X_train.shape[1], activation='gelu'))
# model.add(Dense(9, activation='gelu'))
# model.add(Dense(1, activation='gelu'))
# model.add(Dense(2, activation='softmax'))  # Layer output layer dengan softmax activation untuk klasifikasi binary
# model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# model.fit(X_train, y_train, epochs=100, batch_size=10, verbose=1)
# y_pred_train = model.predict(X_train)
# y_pred_train = (y_pred_train.argmax(axis=1)).astype(int)
# y_pred_test = model.predict(X_test)
# y_pred_test = (y_pred_test.argmax(axis=1)).astype(int)
# y_train_single = y_train.argmax(axis=1)
# y_test_single = y_test.argmax(axis=1)

# Menggunakan SELU Activation
# model = Sequential()
# model.add(Dense(6, input_dim=X_train.shape[1], activation='selu'))
# model.add(Dense(9, activation='selu'))
# model.add(Dense(1, activation='selu'))
# model.add(Dense(2, activation='softmax'))  # Layer output layer dengan softmax activation untuk klasifikasi binary
# model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# model.fit(X_train, y_train, epochs=100, batch_size=10, verbose=1)
# y_pred_train = model.predict(X_train)
# y_pred_train = (y_pred_train.argmax(axis=1)).astype(int)
# y_pred_test = model.predict(X_test)
# y_pred_test = (y_pred_test.argmax(axis=1)).astype(int)
# y_train_single = y_train.argmax(axis=1)
# y_test_single = y_test.argmax(axis=1)

# Menggunakan Binary Step Activation
# model = Sequential()
# model.add(Dense(6, input_dim=X_train.shape[1]))
# model.add(Activation(binary_step))
# model.add(Dense(9))
# model.add(Activation(binary_step))
# model.add(Dense(1))
# model.add(Activation(binary_step))
# model.add(Dense(2, activation='softmax'))  # Layer output layer dengan softmax activation untuk klasifikasi binary
# model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# model.fit(X_train, y_train, epochs=100, batch_size=10, verbose=1)
# y_pred_train = model.predict(X_train)
# y_pred_train = (y_pred_train.argmax(axis=1)).astype(int)
# y_pred_test = model.predict(X_test)
# y_pred_test = (y_pred_test.argmax(axis=1)).astype(int)
# y_train_single = y_train.argmax(axis=1)
# y_test_single = y_test.argmax(axis=1)

# Menggunakan Linear Activation
model = Sequential()
model.add(Dense(6, input_dim=X_train.shape[1], activation='linear'))
model.add(Dense(9, activation='linear'))
model.add(Dense(1, activation='linear'))
model.add(Dense(2, activation='softmax'))  # Layer output layer dengan softmax activation untuk klasifikasi binary
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=100, batch_size=10, verbose=1)
y_pred_train = model.predict(X_train)
y_pred_train = (y_pred_train.argmax(axis=1)).astype(int)
y_pred_test = model.predict(X_test)
y_pred_test = (y_pred_test.argmax(axis=1)).astype(int)
y_train_single = y_train.argmax(axis=1)
y_test_single = y_test.argmax(axis=1)
# Out:
# Epoch 1/100
# 54/54 [==============================] - 1s 2ms/step - loss: 0.6579 - accuracy: 0.6667
# Epoch 2/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6483 - accuracy: 0.6667
# Epoch 3/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6440 - accuracy: 0.6685
# Epoch 4/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6328 - accuracy: 0.6667
# Epoch 5/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6230 - accuracy: 0.6667
# Epoch 6/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6138 - accuracy: 0.6667
# Epoch 7/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6020 - accuracy: 0.6797
# Epoch 8/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5896 - accuracy: 0.7114
# Epoch 9/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5802 - accuracy: 0.6778
# Epoch 10/100
# ...

# %% [markdown]
# Evaluasi dari model yang digunakan

# %%
from sklearn.metrics import classification_report, confusion_matrix

# Menggunakan ReLu, Sigmoid/Logistic, dan Tanh Activation
# print(confusion_matrix(y_train, predict_train))
# print(classification_report(y_train, predict_train))

# Menggunakan Leaky ReLu, Parametric ReLu, dan ELU Activation
# print(confusion_matrix(y_train, y_pred_train))
# print(classification_report(y_train, y_pred_train))

# Menggunakan Softmax, Swish, GELU, SELU, Binary Step, dan Linear Activation
print(confusion_matrix(y_train_single, y_pred_train))
print(classification_report(y_train_single, y_pred_train))
# Out:
# [[318  40]
#  [ 72 107]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.89      0.85       358
#            1       0.73      0.60      0.66       179
#
#     accuracy                           0.79       537
#    macro avg       0.77      0.74      0.75       537
# weighted avg       0.79      0.79      0.79       537
