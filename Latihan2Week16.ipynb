# %% [markdown]
# <a href="https://colab.research.google.com/github/RatihParamita/dataMining/blob/main/Latihan2Week16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('Dataset Valentine.csv')
print(df.shape)
print("Deskripsi data:")
df.describe(include='all').transpose()
# Out:
# (20000, 10)
# Deskripsi data:
#                       count unique              top   freq         mean  \
# Name                  20000  17795  Michael Johnson     13          NaN
# Age                 20000.0    NaN              NaN    NaN      29.0338
# Gender                20000      2             Male  10047          NaN
# Income              20000.0    NaN              NaN    NaN  50051.03415
# Appearance_Score    20000.0    NaN              NaN    NaN    50.136727
# Interests_Score     20000.0    NaN              NaN    NaN    49.950643
# Confidence_Score    20000.0    NaN              NaN    NaN    49.913995
# Educational_Status    20000      4      High School   5107          NaN
# Job_Type              20000      2         Employed  10014          NaN
# Valentine_Date      20000.0    NaN              NaN    NaN       0.4933
#
#                              std      min       25%      50%      75%      max
# ...

# %%
print("Fitur-fitur dalam dataset:")
print(df.columns)
# Out:
# Fitur-fitur dalam dataset:
# Index(['Name', 'Age', 'Gender', 'Income', 'Appearance_Score',
#        'Interests_Score', 'Confidence_Score', 'Educational_Status', 'Job_Type',
#        'Valentine_Date'],
#       dtype='object')

# %%
target_column = 'Valentine_Date'
print(f"Kolom target: {target_column}")
# Out:
# Kolom target: Valentine_Date
